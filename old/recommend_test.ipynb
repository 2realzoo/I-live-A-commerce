# %%
import os
import sys
import urllib.request
import json
import pandas as pd
from dotenv import load_dotenv

# %%
load_dotenv()
client_id = os.getenv('NAVER_API_CLIENT_ID')
client_secret = os.getenv('NAVER_API_CLIENT_SECRET')

# %%
def get_search_url(search_txt, start_pg, disp_num):
    base = 'https://openapi.naver.com/v1/search/shop.json'
    query = '?query=' + urllib.parse.quote(search_txt)
    start = f'&start={start_pg}'
    disp = f'&display={disp_num}'
    url = base + query + disp + start    
    return url

# %%
def get_search_result(url):
    request = urllib.request.Request(url)
    request.add_header('X-Naver-Client-Id', client_id)
    request.add_header('X-Naver-Client-Secret', client_secret)
    response = urllib.request.urlopen(request)
    return json.loads(response.read().decode('utf-8'))

# %%
def delete_tag(input_str):
    input_str = input_str.replace('<b>', '')
    input_str = input_str.replace('</b>', '')
    input_str = input_str.replace('\xa0', '')
    return input_str

# %%
def get_frame(json_data):
    title = [delete_tag(each['title']) for each in json_data['items']]
    lprice = [each['lprice'] for each in json_data['items']]
    link = [each['link'] for each in json_data['items']]
    mall_name = [each['mallName'] for each in json_data['items']]
    product_type = [each['productType'] for each in json_data['items']]
    brand = [each['brand'] for each in json_data['items']]
    category1 = [each['category1'] for each in json_data['items']]
    category2 = [each['category2'] for each in json_data['items']]
    category3 = [each['category3'] for each in json_data['items']]
    category4 = [each['category4'] for each in json_data['items']]
       
    df = pd.DataFrame({
        'title':title,
        'lprice':lprice,
        'link':link,
        'mall':mall_name,
        'category':product_type,
        'brand':brand,
        'category1':category1,
        'category2':category2,
        'category3':category3,
        'category4':category4,        
    }, columns=['title', 'lprice', 'link', 'mall', 'brand', 'category', 'category1', 'category2', 'category3', 'category4'])
    
    return df

# %%
url = get_search_url('화장품',1,50) # 반복문 돌려야함
json_data = get_search_result(url)
df = get_frame(json_data)

# %%
df.head()
# Out:
#                      title  lprice  \
# 0             설화수 자음 2종 세트   38210
# 1           설화수 탄력 크림 75ml   36690
# 2      키엘 울트라 훼이셜 크림 125ml   19990
# 3             인셀덤 기초 5종 세트  101590
# 4  닥터지 레드 블레미쉬 클리어 크림 70ml    5580
#
#                                                 link mall brand category  \
# 0  https://search.shopping.naver.com/catalog/3008...  네이버   설화수        1
# 1  https://search.shopping.naver.com/catalog/4157...  네이버   설화수        1
# 2  https://search.shopping.naver.com/catalog/2109...  네이버    키엘        1
# 3  https://search.shopping.naver.com/catalog/2838...  네이버   인셀덤        1
# 4  https://search.shopping.naver.com/catalog/8863...  네이버   닥터지        1
#
#   category1 category2 category3 category4
# 0    화장품/미용      스킨케어     화장품세트
# 1    화장품/미용      스킨케어        크림
# 2    화장품/미용      스킨케어        크림
# 3    화장품/미용      스킨케어     화장품세트
# 4    화장품/미용      스킨케어        크림

# %%
df['lprice'] = df['lprice'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      50 non-null     object
#  1   lprice     50 non-null     int32
#  2   link       50 non-null     object
#  3   mall       50 non-null     object
#  4   brand      50 non-null     object
#  5   category   50 non-null     object
#  6   category1  50 non-null     object
#  7   category2  50 non-null     object
#  8   category3  50 non-null     object
#  9   category4  50 non-null     object
# dtypes: int32(1), object(9)
# memory usage: 3.8+ KB

# %%
from ast import literal_eval
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
vector = TfidfVectorizer()
vector = CountVectorizer()
a = df['title'] + ' ' + df['mall'] + ' ' + df['brand'] + ' ' + df['category'] + ' ' + df['category1'] + ' ' + df['category2'] + ' ' + df['category3'] + ' ' + df['category4']  
matrix = vector.fit_transform(a)

# %%
user_query = '탄력 크림 에센스 시카'
user_tfidf = vector.transform([user_query])

# %%
similarity_scores = cosine_similarity(user_tfidf, matrix).flatten()

# %%
df['similarity'] = similarity_scores
recommendations = df.sort_values(by='similarity', ascending=False)
recommendations
# Out:
#                                               title  lprice  \
# 1                                    설화수 탄력 크림 75ml   36690
# 31         코스놀로지 덱스판테놀 시카 진정 수분앰플 에센스 수딩젤 대용량 150ml   18900
# 43                        리채움 더 굿 크림 포 모이스처라이징 80ml   29000
# 6                              센텔리안24 더 마데카 크림 50ml    6540
# 41                          코스알엑스 더 레티놀 0.1 크림 20ml   12500
# 9                             에스트라 아토베리어365 크림 80ml   16410
# 13                                  스킨톡 마녀 크림 100ml   16800
# 48                                 제로이드 수딩 크림 160ml   38400
# 47                               키엘 울트라 훼이셜 크림 50ml   19800
# 2                               키엘 울트라 훼이셜 크림 125ml   19990
# 27                            제로이드 인텐시브 크림 엠디 160ml   39000
# 21                         센텔리안24 마데카 크림 타임리버스 50ml    8790
# 18                              설화수 윤조 에센스 6세대 90ml   29700
# 5                                닥터지 블랙 스네일 크림 50ml    8140
# 25                               인셀덤 엑티브 크림 EX 50ml   25130
# 26                            오브네쥬 퍼미에잇 365 크림 50ml   32500
# 14                    에스트라 아토베리어 365 크림 80ml + 30ml   21580
# 22                            닥터지 로얄 블랙 스네일 크림 50ml    8990
# 4                           닥터지 레드 블레미쉬 클리어 크림 70ml    5580
# 24                        김정문알로에 큐어 인텐시브 2X 크림 50ml    5280
# 34                          키엘 울트라 훼이셜 크림 150ml(리필)   34240
# 17                   피지오겔 데일리 모이스쳐 테라피 페이셜 크림 150ml   18140
# 19                    닥터코스모 마이크로 바이옴 리페어 엠엘 크림 50ml   52000
# 35                    센텔리안24 마데카 크림 액티브 스킨 포뮬러 50ml    6290
# 45  코스놀로지 슈퍼 글루타민C 미백 시카 기미 앰플 80ml 잡티 멜라닌 관리 톤업 앰플   24900
# 36                              스킨수티컬즈 C E 페룰릭 30ml   33740
# 40                          라로슈포제 시카플라스트 밤 B5 100ml   14510
# 20                              에스티로더 갈색병 7세대 100ml   59590
# 10                         라로슈포제 시카플라스트 밤 B5+ 100ml   18490
# 46                          라로슈포제 시카플라스트 밤 B5 100ml   18490
# 32                            더마팩토리 PDRN 4% 앰플 30ml   12000
# 38                  디오디너리 나이아신아마이드 10% + 징크 1% 60ml    9180
# 37                           MISSHA 비폴렌 리뉴 앰풀러 40ml   13780
# 49                         톤28 해남404 펩타시카 새벽크림 50ml   22490
# 33                          코스알엑스 더 비타민씨 23 세럼 20ml   11120
# 30                               참존 마유 골든 컴플렉스 70ml   10290
# 29                          브이티코스메틱 VT 리들샷 300 50ml   21410
# 28                    디마르3 시그니처 에스투드 프로텍터 5.2 170ml   29870
# 15                                가히 링클 바운스 멀티밤 9ml   12740
# 12                         에스네이처 아쿠아 스쿠알란 수분크림 60ml   10150
# 11                          브이티코스메틱 VT 리들샷 100 50ml   15890
# 16                   코스알엑스 더 6 펩타이드 스킨 부스터 세럼 150ml    9750
# 7                        토리든 다이브인 저분자 히알루론산 세럼 50ml   12200
# 23                     웰라쥬 리얼 히알루로닉 블루 100 앰플 100ml   19150
# 39                          가히 멀티 밤 리필형 9g + 9g(리필)   22700
# 44    에스티로더 어드밴스드 나이트 리페어 싱크로나이즈드 멀티 리커버리 콤플렉스 50ml   20590
# 42                                 설화수 자음생 EX 2종 세트  121500
# 8                                      설화수 자음 2종 세트   38220
# 3                                      인셀덤 기초 5종 세트  101590
# 0                                      설화수 자음 2종 세트   38210
#
#                                                  link   mall    brand  \
# 1   https://search.shopping.naver.com/catalog/4157...    네이버      설화수
# 31  https://smartstore.naver.com/main/products/105...  코스놀로지    코스놀로지
# 43  https://search.shopping.naver.com/catalog/5139...    네이버
# 6   https://search.shopping.naver.com/catalog/2981...    네이버   센텔리안24
# 41  https://search.shopping.naver.com/catalog/3381...    네이버    코스알엑스
# 9   https://search.shopping.naver.com/catalog/1772...    네이버     에스트라
# 13  https://search.shopping.naver.com/catalog/3024...    네이버      스킨톡
# 48  https://search.shopping.naver.com/catalog/1015...    네이버     제로이드
# 47  https://search.shopping.naver.com/catalog/4048...    네이버       키엘
# 2   https://search.shopping.naver.com/catalog/2109...    네이버       키엘
# 27  https://search.shopping.naver.com/catalog/3520...    네이버     제로이드
# 21  https://search.shopping.naver.com/catalog/4408...    네이버   센텔리안24
# 18  https://search.shopping.naver.com/catalog/4145...    네이버      설화수
# 5   https://search.shopping.naver.com/catalog/1418...    네이버      닥터지
# 25  https://search.shopping.naver.com/catalog/2673...    네이버      인셀덤
# 26  https://search.shopping.naver.com/catalog/5097...    네이버     오브네쥬
# 14  https://search.shopping.naver.com/catalog/3103...    네이버     에스트라
# 22  https://search.shopping.naver.com/catalog/2079...    네이버      닥터지
# 4   https://search.shopping.naver.com/catalog/8863...    네이버      닥터지
# 24  https://search.shopping.naver.com/catalog/1545...    네이버   김정문알로에
# 34  https://search.shopping.naver.com/catalog/3402...    네이버       키엘
# 17  https://search.shopping.naver.com/catalog/2242...    네이버     피지오겔
# 19  https://search.shopping.naver.com/catalog/4870...    네이버    닥터코스모
# 35  https://search.shopping.naver.com/catalog/2190...    네이버   센텔리안24
# 45  https://smartstore.naver.com/main/products/102...  코스놀로지    코스놀로지
# 36  https://search.shopping.naver.com/catalog/2600...    네이버   스킨수티컬즈
# 40  https://search.shopping.naver.com/catalog/2325...    네이버    라로슈포제
# 20  https://search.shopping.naver.com/catalog/3635...    네이버    에스티로더
# 10  https://search.shopping.naver.com/catalog/3541...    네이버    라로슈포제
# 46  https://search.shopping.naver.com/catalog/8119...    네이버    라로슈포제
# 32  https://search.shopping.naver.com/catalog/5037...    네이버    더마팩토리
# 38  https://search.shopping.naver.com/catalog/2821...    네이버    디오디너리
# 37  https://search.shopping.naver.com/catalog/1435...    네이버   MISSHA
# 49  https://search.shopping.naver.com/catalog/4250...    네이버      톤28
# 33  https://search.shopping.naver.com/catalog/3241...    네이버    코스알엑스
# 30  https://search.shopping.naver.com/catalog/1130...    네이버       참존
# 29  https://search.shopping.naver.com/catalog/3930...    네이버  브이티코스메틱
# 28  https://search.shopping.naver.com/catalog/3151...    네이버     디마르3
# 15  https://search.shopping.naver.com/catalog/2256...    네이버       가히
# 12  https://search.shopping.naver.com/catalog/2430...    네이버    에스네이처
# 11  https://search.shopping.naver.com/catalog/3930...    네이버  브이티코스메틱
# 16  https://search.shopping.naver.com/catalog/4290...    네이버    코스알엑스
# 7   https://search.shopping.naver.com/catalog/2084...    네이버      토리든
# 23  https://search.shopping.naver.com/catalog/2409...    네이버      웰라쥬
# 39  https://search.shopping.naver.com/catalog/3746...    네이버       가히
# 44  https://search.shopping.naver.com/catalog/2463...    네이버    에스티로더
# 42  https://search.shopping.naver.com/catalog/3245...    네이버      설화수
# 8   https://search.shopping.naver.com/catalog/4157...    네이버      설화수
# 3   https://search.shopping.naver.com/catalog/2838...    네이버      인셀덤
# 0   https://search.shopping.naver.com/catalog/3008...    네이버      설화수
#
#    category category1 category2 category3 category4  similarity
# 1         1    화장품/미용      스킨케어        크림              0.400892
# 31        2    화장품/미용      스킨케어       에센스              0.312772
# 43        1    화장품/미용      스킨케어        크림              0.301511
# 6         1    화장품/미용      스킨케어        크림              0.267261
# 41        1    화장품/미용      스킨케어        크림              0.267261
# 9         1    화장품/미용      스킨케어        크림              0.267261
# 13        1    화장품/미용      스킨케어        크림              0.267261
# 48        1    화장품/미용      스킨케어        크림              0.267261
# 47        1    화장품/미용      스킨케어        크림              0.258199
# 2         1    화장품/미용      스킨케어        크림              0.258199
# 27        1    화장품/미용      스킨케어        크림              0.258199
# 21        1    화장품/미용      스킨케어        크림              0.258199
# 18        1    화장품/미용      스킨케어       에센스              0.258199
# 5         1    화장품/미용      스킨케어        크림              0.258199
# 25        1    화장품/미용      스킨케어        크림              0.258199
# 26        1    화장품/미용      스킨케어        크림              0.258199
# 14        1    화장품/미용      스킨케어        크림              0.250000
# 22        1    화장품/미용      스킨케어        크림              0.250000
# 4         1    화장품/미용      스킨케어        크림              0.250000
# 24        1    화장품/미용      스킨케어        크림              0.250000
# 34        1    화장품/미용      스킨케어        크림              0.250000
# 17        1    화장품/미용      스킨케어        크림              0.242536
# 19        1    화장품/미용      스킨케어        크림              0.242536
# 35        1    화장품/미용      스킨케어        크림              0.242536
# 45        2    화장품/미용      스킨케어       에센스              0.192450
# 36        1    화장품/미용      스킨케어       에센스              0.150756
# 40        1    화장품/미용      스킨케어        크림              0.144338
# 20        1    화장품/미용      스킨케어       에센스              0.144338
# 10        1    화장품/미용      스킨케어        크림              0.144338
# 46        1    화장품/미용      스킨케어        크림              0.144338
# 32        1    화장품/미용      스킨케어       에센스              0.144338
# 38        1    화장품/미용      스킨케어       에센스              0.138675
# 37        1    화장품/미용      스킨케어       에센스              0.138675
# 49        1    화장품/미용      스킨케어        크림              0.138675
# 33        1    화장품/미용      스킨케어       에센스              0.138675
# 30        1    화장품/미용      스킨케어        크림              0.138675
# 29        1    화장품/미용      스킨케어       에센스              0.138675
# 28        1    화장품/미용      스킨케어       에센스              0.138675
# 15        1    화장품/미용      스킨케어        크림              0.138675
# 12        1    화장품/미용      스킨케어        크림              0.138675
# 11        1    화장품/미용      스킨케어       에센스              0.138675
# 16        1    화장품/미용      스킨케어       에센스              0.133631
# 7         1    화장품/미용      스킨케어       에센스              0.133631
# 23        1    화장품/미용      스킨케어       에센스              0.129099
# 39        1    화장품/미용      스킨케어        크림              0.125000
# 44        1    화장품/미용      스킨케어       에센스              0.121268
# 42        1    화장품/미용      스킨케어     화장품세트              0.000000
# 8         1    화장품/미용      스킨케어     화장품세트              0.000000
# 3         1    화장품/미용      스킨케어     화장품세트              0.000000
# 0         1    화장품/미용      스킨케어     화장품세트              0.000000

# %%
df = pd.DataFrame({}, columns=['title', 'lprice', 'link', 'mall', 'brand', 'category', 'category1', 'category2', 'category3', 'category4']) 
for idx in range(1,100):
    url = get_search_url('사과', idx, 100)
    json_data = get_search_result(url)
    try_df = get_frame(json_data)
    df = pd.concat([df, try_df])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[280], line 4
#       2 for idx in range(1,100):
#       3     url = get_search_url('사과', idx, 100)
# ----> 4     json_data = get_search_result(url)
#       5     try_df = get_frame(json_data)
#       6     df = pd.concat([df, try_df])
#
# Cell In[241], line 5, in get_search_result(url)
#       3 request.add_header('X-Naver-Client-Id', client_id)
#       4 request.add_header('X-Naver-Client-Secret', client_secret)
# ----> 5 response = urllib.request.urlopen(request)
#       6 return json.loads(response.read().decode('utf-8'))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:215, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213 else:
#     214     opener = _opener
# --> 215 return opener.open(url, data, timeout)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:515, in OpenerDirector.open(self, fullurl, data, timeout)
#     512     req = meth(req)
#     514 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 515 response = self._open(req, data)
#     517 # post-process response
#     518 meth_name = protocol+"_response"
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:532, in OpenerDirector._open(self, req, data)
#     529     return result
#     531 protocol = req.type
# --> 532 result = self._call_chain(self.handle_open, protocol, protocol +
#     533                           '_open', req)
#     534 if result:
#     535     return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:492, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     490 for handler in handlers:
#     491     func = getattr(handler, meth_name)
# --> 492     result = func(*args)
#     493     if result is not None:
#     494         return result
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:1392, in HTTPSHandler.https_open(self, req)
#    1391 def https_open(self, req):
# -> 1392     return self.do_open(http.client.HTTPSConnection, req,
#    1393                         context=self._context)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\urllib\request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1342 try:
#    1343     try:
# -> 1344         h.request(req.get_method(), req.selector, req.data, headers,
#    1345                   encode_chunked=req.has_header('Transfer-encoding'))
#    1346     except OSError as err: # timeout error
#    1347         raise URLError(err)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1336, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1333 def request(self, method, url, body=None, headers={}, *,
#    1334             encode_chunked=False):
#    1335     """Send a complete request to the server."""
# -> 1336     self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1382, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1378 if isinstance(body, str):
#    1379     # RFC 2616 Section 3.7.1 says that text default has a
#    1380     # default charset of iso-8859-1.
#    1381     body = _encode(body, 'body')
# -> 1382 self.endheaders(body, encode_chunked=encode_chunked)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1331, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1329 else:
#    1330     raise CannotSendHeader()
# -> 1331 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1091, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1089 msg = b"\r\n".join(self._buffer)
#    1090 del self._buffer[:]
# -> 1091 self.send(msg)
#    1093 if message_body is not None:
#    1094
#    1095     # create a consistent interface to message_body
#    1096     if hasattr(message_body, 'read'):
#    1097         # Let file-like take precedence over byte-like.  This
#    1098         # is needed to allow the current position of mmap'ed
#    1099         # files to be taken into account.
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1035, in HTTPConnection.send(self, data)
#    1033 if self.sock is None:
#    1034     if self.auto_open:
# -> 1035         self.connect()
#    1036     else:
#    1037         raise NotConnected()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1470, in HTTPSConnection.connect(self)
#    1467 def connect(self):
#    1468     "Connect to a host on a given (SSL) port."
# -> 1470     super().connect()
#    1472     if self._tunnel_host:
#    1473         server_hostname = self._tunnel_host
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\http\client.py:1001, in HTTPConnection.connect(self)
#     999 """Connect to the host and port specified in __init__."""
#    1000 sys.audit("http.client.connect", self, self.host, self.port)
# -> 1001 self.sock = self._create_connection(
#    1002     (self.host,self.port), self.timeout, self.source_address)
#    1003 # Might fail in OSs that don't implement TCP_NODELAY
#    1004 try:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\socket.py:829, in create_connection(address, timeout, source_address, all_errors)
#     827 host, port = address
#     828 exceptions = []
# --> 829 for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     830     af, socktype, proto, canonname, sa = res
#     831     sock = None
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\socket.py:964, in getaddrinfo(host, port, family, type, proto, flags)
#     961 # We override this function since we want to translate the numeric family
#     962 # and socket type values to enum constants.
#     963 addrlist = []
# --> 964 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     965     af, socktype, proto, canonname, sa = res
#     966     addrlist.append((_intenum_converter(af, AddressFamily),
#     967                      _intenum_converter(socktype, SocketKind),
#     968                      proto, canonname, sa))
#
# KeyboardInterrupt:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9900 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      9900 non-null   object
#  1   lprice     9900 non-null   object
#  2   link       9900 non-null   object
#  3   mall       9900 non-null   object
#  4   brand      9900 non-null   object
#  5   category   9900 non-null   object
#  6   category1  9900 non-null   object
#  7   category2  9900 non-null   object
#  8   category3  9900 non-null   object
#  9   category4  9900 non-null   object
# dtypes: object(10)
# memory usage: 850.8+ KB

# %%
df = df.astype({"title" : "str", "lprice" : "int", 'category' : 'str'})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9900 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      9900 non-null   object
#  1   lprice     9900 non-null   int32
#  2   link       9900 non-null   object
#  3   mall       9900 non-null   object
#  4   brand      9900 non-null   object
#  5   category   9900 non-null   object
#  6   category1  9900 non-null   object
#  7   category2  9900 non-null   object
#  8   category3  9900 non-null   object
#  9   category4  9900 non-null   object
# dtypes: int32(1), object(9)
# memory usage: 812.1+ KB
